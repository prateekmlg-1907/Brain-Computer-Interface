# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_curve, auc, precision_recall_curve, average_precision_score
)
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout, Input, Bidirectional
from tensorflow.keras.optimizers import Adam
import joblib

# %%
df = pd.read_csv('/content/drive/MyDrive/Final Project/DataSet/thinking.csv')

X = df[['F3', 'FC5', 'AF3', 'F7', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'F8', 'AF4', 'FC6', 'F4']]
y = df['Label']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
X_test_normalized = (X_test - X_test.min()) / (X_test.max() - X_test.min())
X_train_nn = np.expand_dims(X_train_normalized.values, axis=1)
X_test_nn = np.expand_dims(X_test_normalized.values, axis=1)

# %%
class_weights = compute_class_weight(
    class_weight='balanced', classes=np.unique(y_train), y=y_train
)
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
rnn_model = Sequential([
    Input(shape=(X_train_nn.shape[1], X_train_nn.shape[2])),
    Bidirectional(SimpleRNN(64, activation='relu')), 
    Dropout(0.3),
    Dense(len(np.unique(y_train)), activation='softmax') 
])
rnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = rnn_model.fit(X_train_nn, y_train, epochs=50, batch_size=32, validation_split=0.2, class_weight=class_weight_dict)

y_pred_proba = rnn_model.predict(X_test_nn)
y_pred = np.argmax(y_pred_proba, axis=1)
# Out:
# Epoch 1/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 27s 2ms/step - accuracy: 0.0635 - loss: 2.7743 - val_accuracy: 0.0654 - val_loss: 2.7719
# Epoch 2/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.0662 - loss: 2.7717 - val_accuracy: 0.0687 - val_loss: 2.7700
# Epoch 3/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0685 - loss: 2.7694 - val_accuracy: 0.0677 - val_loss: 2.7694
# Epoch 4/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0711 - loss: 2.7657 - val_accuracy: 0.0799 - val_loss: 2.7625
# Epoch 5/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.0742 - loss: 2.7619 - val_accuracy: 0.0745 - val_loss: 2.7584
# Epoch 6/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.0770 - loss: 2.7577 - val_accuracy: 0.0862 - val_loss: 2.7499
# Epoch 7/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.0793 - loss: 2.7535 - val_accuracy: 0.0786 - val_loss: 2.7463
# Epoch 8/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.0807 - loss: 2.7499 - val_accuracy: 0.0836 - val_loss: 2.7435
# Epoch 9/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.0820 - loss: 2.7468 - val_accuracy: 0.0879 - val_loss: 2.7398
# Epoch 10/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.0845 - loss: 2.7430 - val_accuracy: 0.0950 - val_loss: 2.7343
# Epoch 11/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.0868 - loss: 2.7386 - val_accuracy: 0.0857 - val_loss: 2.7335
# Epoch 12/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.0876 - loss: 2.7375 - val_accuracy: 0.0934 - val_loss: 2.7281
# Epoch 13/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.0882 - loss: 2.7341 - val_accuracy: 0.0953 - val_loss: 2.7241
# Epoch 14/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - accuracy: 0.0894 - loss: 2.7316 - val_accuracy: 0.0974 - val_loss: 2.7191
# Epoch 15/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0910 - loss: 2.7285 - val_accuracy: 0.0923 - val_loss: 2.7227
# Epoch 16/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.0919 - loss: 2.7255 - val_accuracy: 0.0890 - val_loss: 2.7188
# Epoch 17/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.0924 - loss: 2.7243 - val_accuracy: 0.1020 - val_loss: 2.7114
# Epoch 18/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0934 - loss: 2.7215 - val_accuracy: 0.0958 - val_loss: 2.7109
# Epoch 19/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.0946 - loss: 2.7198 - val_accuracy: 0.1001 - val_loss: 2.7095
# Epoch 20/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.0968 - loss: 2.7162 - val_accuracy: 0.0975 - val_loss: 2.7086
# Epoch 21/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.0962 - loss: 2.7158 - val_accuracy: 0.0844 - val_loss: 2.7113
# Epoch 22/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0964 - loss: 2.7138 - val_accuracy: 0.1049 - val_loss: 2.6990
# Epoch 23/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.0970 - loss: 2.7114 - val_accuracy: 0.1013 - val_loss: 2.7027
# Epoch 24/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.0983 - loss: 2.7108 - val_accuracy: 0.1032 - val_loss: 2.6995
# Epoch 25/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.0985 - loss: 2.7088 - val_accuracy: 0.1058 - val_loss: 2.6942
# Epoch 26/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.0991 - loss: 2.7082 - val_accuracy: 0.1094 - val_loss: 2.6932
# Epoch 27/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.0993 - loss: 2.7061 - val_accuracy: 0.1068 - val_loss: 2.6913
# Epoch 28/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.0997 - loss: 2.7060 - val_accuracy: 0.1031 - val_loss: 2.6927
# Epoch 29/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.0997 - loss: 2.7045 - val_accuracy: 0.1034 - val_loss: 2.6902
# Epoch 30/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.1005 - loss: 2.7035 - val_accuracy: 0.1091 - val_loss: 2.6875
# Epoch 31/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.1006 - loss: 2.7023 - val_accuracy: 0.1100 - val_loss: 2.6835
# Epoch 32/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.1015 - loss: 2.7001 - val_accuracy: 0.1158 - val_loss: 2.6830
# Epoch 33/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.1008 - loss: 2.6990 - val_accuracy: 0.1142 - val_loss: 2.6828
# Epoch 34/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.1034 - loss: 2.6974 - val_accuracy: 0.1139 - val_loss: 2.6807
# Epoch 35/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.1031 - loss: 2.6975 - val_accuracy: 0.1168 - val_loss: 2.6797
# Epoch 36/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.1019 - loss: 2.6967 - val_accuracy: 0.1130 - val_loss: 2.6785
# Epoch 37/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.1029 - loss: 2.6967 - val_accuracy: 0.1095 - val_loss: 2.6784
# Epoch 38/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.1041 - loss: 2.6937 - val_accuracy: 0.1188 - val_loss: 2.6726
# Epoch 39/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.1029 - loss: 2.6945 - val_accuracy: 0.1151 - val_loss: 2.6748
# Epoch 40/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.1043 - loss: 2.6932 - val_accuracy: 0.1168 - val_loss: 2.6695
# Epoch 41/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.1044 - loss: 2.6923 - val_accuracy: 0.1175 - val_loss: 2.6704
# Epoch 42/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.1039 - loss: 2.6923 - val_accuracy: 0.1127 - val_loss: 2.6758
# Epoch 43/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.1042 - loss: 2.6905 - val_accuracy: 0.1119 - val_loss: 2.6688
# Epoch 44/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.1038 - loss: 2.6903 - val_accuracy: 0.1165 - val_loss: 2.6696
# Epoch 45/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.1055 - loss: 2.6883 - val_accuracy: 0.1161 - val_loss: 2.6698
# Epoch 46/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.1051 - loss: 2.6889 - val_accuracy: 0.1203 - val_loss: 2.6636
# Epoch 47/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.1047 - loss: 2.6875 - val_accuracy: 0.1097 - val_loss: 2.6749
# Epoch 48/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.1057 - loss: 2.6872 - val_accuracy: 0.1142 - val_loss: 2.6690
# Epoch 49/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.1060 - loss: 2.6869 - val_accuracy: 0.1188 - val_loss: 2.6649
# Epoch 50/50
# 10752/10752 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.1061 - loss: 2.6866 - val_accuracy: 0.1149 - val_loss: 2.6679
# 5760/5760 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.07483723958333334
# Precision: 0.38748472474631623
# Recall: 0.07483723958333334
# F1 Score: 0.04215694799577212
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - RNN")
plt.show()

# %%
plt.figure(figsize=(8, 6))
n_classes = len(label_encoder.classes_)

for i in range(n_classes):
    fpr, tpr, _ = roc_curve((y_test == i).astype(int), y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {label_encoder.classes_[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve - RNN")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve((y_test == i).astype(int), y_pred_proba[:, i])
    avg_precision = average_precision_score((y_test == i).astype(int), y_pred_proba[:, i])
    plt.plot(recall, precision, label=f"Class {label_encoder.classes_[i]} (AP = {avg_precision:.2f})")

plt.title("Precision-Recall Curve - RNN")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="lower left")
plt.show()

# %%
#metrics
metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1,
    "Confusion Matrix": conf_matrix.tolist()
}

with open('rnn_metrics.txt', 'w') as f:
    f.write("RNN Model Metrics\n")
    f.write("=================\n")
    for key, value in metrics.items():
        if key == "Confusion Matrix":
            f.write(f"{key}:\n")
            for row in value:
                f.write(f"{row}\n")
        else:
            f.write(f"{key}: {value}\n")

print("Metrics saved as 'rnn_metrics.txt'")
# Out:
# Metrics saved as 'rnn_metrics.txt'

# %%
#saving model
rnn_model.save('rnn_model.h5')
print("RNN model saved as 'rnn_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# RNN model saved as 'rnn_model.h5'
